# %%
import pandas as pd
import numpy as np
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://root:root@cluster10.odazv.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
data = pd.read_csv('Datasets/Data_RemoveOutliers')
data.head()
# Out:
#    Temperature  RH  Ws  Rain     FFMC  DMC    DC  ISI  FWI  Classes
# 0           29  57  18  0.00  65.7000  3.4   7.6  1.3  0.5        0
# 1           29  61  13  1.25  64.4000  4.1   7.6  1.0  0.4        0
# 2           26  82  22  1.25  47.7375  2.5   7.1  0.3  0.1        0
# 3           25  89  13  1.25  47.7375  1.3   6.9  0.0  0.0        0
# 4           27  77  16  0.00  64.8000  3.0  14.2  1.2  0.5        0

# %%
new_data = data.iloc[60:120, :8]

# %%
new_data.shape
# Out:
# (60, 8)

# %%
bulk_data = bulk_data.to_dict(orient='records')

# %%
bulk_data
# Out:
# [{'Temperature': 35,
#   'RH': 64,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 87.2,
#   'DMC': 31.9,
#   'DC': 145.7,
#   'ISI': 6.8},
#  {'Temperature': 36,
#   'RH': 45,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 78.8,
#   'DMC': 4.8,
#   'DC': 10.2,
#   'ISI': 2.0},
#  {'Temperature': 35,
#   'RH': 55,
#   'Ws': 12,
#   'Rain': 0.4,
#   'FFMC': 78.0,
#   'DMC': 5.8,
#   'DC': 10.0,
#   'ISI': 1.7},
#  {'Temperature': 35,
#   'RH': 63,
#   'Ws': 14,
#   'Rain': 0.3,
#   'FFMC': 76.6,
#   'DMC': 5.7,
#   'DC': 10.0,
#   'ISI': 1.7},
#  {'Temperature': 34,
#   'RH': 69,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 85.0,
#   'DMC': 8.2,
#   'DC': 19.8,
#   'ISI': 4.0},
#  {'Temperature': 34,
#   'RH': 65,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 86.8,
#   'DMC': 11.1,
#   'DC': 29.7,
#   'ISI': 5.2},
#  {'Temperature': 32,
#   'RH': 75,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 86.4,
#   'DMC': 13.0,
#   'DC': 39.1,
#   'ISI': 5.2},
#  {'Temperature': 32,
#   'RH': 69,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 86.5,
#   'DMC': 15.5,
#   'DC': 48.6,
#   'ISI': 5.5},
#  {'Temperature': 32,
#   'RH': 60,
#   'Ws': 18,
#   'Rain': 0.3,
#   'FFMC': 77.1,
#   'DMC': 11.3,
#   'DC': 47.0,
#   'ISI': 2.2},
#  {'Temperature': 35,
#   'RH': 59,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 87.4,
#   'DMC': 14.8,
#   'DC': 57.0,
#   'ISI': 6.9},
#  {'Temperature': 35,
#   'RH': 55,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 18.6,
#   'DC': 67.0,
#   'ISI': 7.4},
#  {'Temperature': 35,
#   'RH': 63,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 21.7,
#   'DC': 77.0,
#   'ISI': 7.1},
#  {'Temperature': 35,
#   'RH': 51,
#   'Ws': 13,
#   'Rain': 0.3,
#   'FFMC': 81.3,
#   'DMC': 15.6,
#   'DC': 75.1,
#   'ISI': 2.5},
#  {'Temperature': 35,
#   'RH': 63,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 87.0,
#   'DMC': 19.0,
#   'DC': 85.1,
#   'ISI': 5.9},
#  {'Temperature': 33,
#   'RH': 66,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 87.0,
#   'DMC': 21.7,
#   'DC': 94.7,
#   'ISI': 5.7},
#  {'Temperature': 36,
#   'RH': 55,
#   'Ws': 13,
#   'Rain': 0.3,
#   'FFMC': 82.4,
#   'DMC': 15.6,
#   'DC': 92.5,
#   'ISI': 3.7},
#  {'Temperature': 36,
#   'RH': 61,
#   'Ws': 18,
#   'Rain': 0.3,
#   'FFMC': 80.2,
#   'DMC': 11.7,
#   'DC': 90.4,
#   'ISI': 2.8},
#  {'Temperature': 37,
#   'RH': 52,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 89.3,
#   'DMC': 16.0,
#   'DC': 100.7,
#   'ISI': 9.7},
#  {'Temperature': 36,
#   'RH': 54,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 20.0,
#   'DC': 110.9,
#   'ISI': 9.7},
#  {'Temperature': 35,
#   'RH': 62,
#   'Ws': 19,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 23.2,
#   'DC': 120.9,
#   'ISI': 9.7},
#  {'Temperature': 35,
#   'RH': 68,
#   'Ws': 19,
#   'Rain': 0.0,
#   'FFMC': 88.3,
#   'DMC': 25.9,
#   'DC': 130.6,
#   'ISI': 8.8},
#  {'Temperature': 36,
#   'RH': 58,
#   'Ws': 19,
#   'Rain': 0.0,
#   'FFMC': 88.6,
#   'DMC': 29.6,
#   'DC': 141.1,
#   'ISI': 9.2},
#  {'Temperature': 36,
#   'RH': 55,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 89.1,
#   'DMC': 33.5,
#   'DC': 150.46250000000003,
#   'ISI': 9.9},
#  {'Temperature': 36,
#   'RH': 53,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 89.5,
#   'DMC': 37.6,
#   'DC': 150.46250000000003,
#   'ISI': 10.4},
#  {'Temperature': 34,
#   'RH': 64,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 40.5,
#   'DC': 150.46250000000003,
#   'ISI': 9.0},
#  {'Temperature': 35,
#   'RH': 60,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 43.175,
#   'DC': 150.46250000000003,
#   'ISI': 8.2},
#  {'Temperature': 31,
#   'RH': 78,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 85.8,
#   'DMC': 43.175,
#   'DC': 150.46250000000003,
#   'ISI': 4.7},
#  {'Temperature': 33,
#   'RH': 82,
#   'Ws': 21,
#   'Rain': 0.0,
#   'FFMC': 84.9,
#   'DMC': 43.175,
#   'DC': 150.46250000000003,
#   'ISI': 4.4},
#  {'Temperature': 34,
#   'RH': 64,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 43.175,
#   'DC': 150.46250000000003,
#   'ISI': 7.3},
#  {'Temperature': 35,
#   'RH': 48,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 90.1,
#   'DMC': 43.175,
#   'DC': 150.46250000000003,
#   'ISI': 12.5},
#  {'Temperature': 35,
#   'RH': 70,
#   'Ws': 17,
#   'Rain': 0.8,
#   'FFMC': 72.7,
#   'DMC': 25.2,
#   'DC': 150.46250000000003,
#   'ISI': 1.7},
#  {'Temperature': 28,
#   'RH': 80,
#   'Ws': 21,
#   'Rain': 1.25,
#   'FFMC': 52.5,
#   'DMC': 8.7,
#   'DC': 8.7,
#   'ISI': 0.6},
#  {'Temperature': 25,
#   'RH': 76,
#   'Ws': 17,
#   'Rain': 1.25,
#   'FFMC': 47.73750000000001,
#   'DMC': 1.3,
#   'DC': 7.5,
#   'ISI': 0.2},
#  {'Temperature': 22,
#   'RH': 86,
#   'Ws': 15,
#   'Rain': 1.25,
#   'FFMC': 47.73750000000001,
#   'DMC': 0.7,
#   'DC': 7.0,
#   'ISI': 0.0},
#  {'Temperature': 25,
#   'RH': 78,
#   'Ws': 15,
#   'Rain': 1.25,
#   'FFMC': 47.73750000000001,
#   'DMC': 1.2,
#   'DC': 7.5,
#   'ISI': 0.1},
#  {'Temperature': 29,
#   'RH': 73,
#   'Ws': 17,
#   'Rain': 0.1,
#   'FFMC': 68.4,
#   'DMC': 1.9,
#   'DC': 15.7,
#   'ISI': 1.4},
#  {'Temperature': 29,
#   'RH': 75,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 80.8,
#   'DMC': 3.4,
#   'DC': 24.0,
#   'ISI': 2.8},
#  {'Temperature': 29,
#   'RH': 74,
#   'Ws': 19,
#   'Rain': 0.1,
#   'FFMC': 75.8,
#   'DMC': 3.6,
#   'DC': 32.2,
#   'ISI': 2.1},
#  {'Temperature': 31,
#   'RH': 71,
#   'Ws': 17,
#   'Rain': 0.3,
#   'FFMC': 69.6,
#   'DMC': 3.2,
#   'DC': 30.1,
#   'ISI': 1.5},
#  {'Temperature': 30,
#   'RH': 73,
#   'Ws': 17,
#   'Rain': 0.9,
#   'FFMC': 62.0,
#   'DMC': 2.6,
#   'DC': 8.4,
#   'ISI': 1.1},
#  {'Temperature': 30,
#   'RH': 77,
#   'Ws': 15,
#   'Rain': 1.0,
#   'FFMC': 56.1,
#   'DMC': 2.1,
#   'DC': 8.4,
#   'ISI': 0.7},
#  {'Temperature': 33,
#   'RH': 73,
#   'Ws': 12,
#   'Rain': 1.25,
#   'FFMC': 59.9,
#   'DMC': 2.2,
#   'DC': 8.9,
#   'ISI': 0.7},
#  {'Temperature': 30,
#   'RH': 77,
#   'Ws': 21,
#   'Rain': 1.25,
#   'FFMC': 58.5,
#   'DMC': 1.9,
#   'DC': 8.4,
#   'ISI': 1.1},
#  {'Temperature': 29,
#   'RH': 88,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 71.0,
#   'DMC': 2.6,
#   'DC': 16.6,
#   'ISI': 1.2},
#  {'Temperature': 25,
#   'RH': 86,
#   'Ws': 21,
#   'Rain': 1.25,
#   'FFMC': 47.73750000000001,
#   'DMC': 1.3,
#   'DC': 7.5,
#   'ISI': 0.1},
#  {'Temperature': 22,
#   'RH': 76,
#   'Ws': 26,
#   'Rain': 1.25,
#   'FFMC': 47.73750000000001,
#   'DMC': 1.1,
#   'DC': 7.0,
#   'ISI': 0.4},
#  {'Temperature': 24,
#   'RH': 82,
#   'Ws': 15,
#   'Rain': 0.4,
#   'FFMC': 47.73750000000001,
#   'DMC': 0.9,
#   'DC': 7.3,
#   'ISI': 0.2},
#  {'Temperature': 30,
#   'RH': 65,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 78.1,
#   'DMC': 3.2,
#   'DC': 15.7,
#   'ISI': 1.9},
#  {'Temperature': 31,
#   'RH': 52,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 87.7,
#   'DMC': 6.4,
#   'DC': 24.3,
#   'ISI': 6.2},
#  {'Temperature': 32,
#   'RH': 49,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 9.8,
#   'DC': 33.1,
#   'ISI': 6.8},
#  {'Temperature': 29,
#   'RH': 57,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 89.3,
#   'DMC': 12.5,
#   'DC': 41.3,
#   'ISI': 7.8},
#  {'Temperature': 28,
#   'RH': 84,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 83.8,
#   'DMC': 13.5,
#   'DC': 49.3,
#   'ISI': 4.5},
#  {'Temperature': 31,
#   'RH': 55,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 87.8,
#   'DMC': 16.5,
#   'DC': 57.9,
#   'ISI': 5.4},
#  {'Temperature': 31,
#   'RH': 50,
#   'Ws': 19,
#   'Rain': 0.6,
#   'FFMC': 77.8,
#   'DMC': 10.6,
#   'DC': 41.4,
#   'ISI': 2.4},
#  {'Temperature': 32,
#   'RH': 54,
#   'Ws': 11,
#   'Rain': 0.5,
#   'FFMC': 73.7,
#   'DMC': 7.9,
#   'DC': 30.4,
#   'ISI': 1.2},
#  {'Temperature': 29,
#   'RH': 65,
#   'Ws': 19,
#   'Rain': 0.6,
#   'FFMC': 68.3,
#   'DMC': 5.5,
#   'DC': 15.2,
#   'ISI': 1.5},
#  {'Temperature': 26,
#   'RH': 81,
#   'Ws': 21,
#   'Rain': 1.25,
#   'FFMC': 48.6,
#   'DMC': 3.0,
#   'DC': 7.7,
#   'ISI': 0.4},
#  {'Temperature': 31,
#   'RH': 54,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 82.0,
#   'DMC': 6.0,
#   'DC': 16.3,
#   'ISI': 2.5},
#  {'Temperature': 31,
#   'RH': 66,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 85.7,
#   'DMC': 8.3,
#   'DC': 24.9,
#   'ISI': 4.0},
#  {'Temperature': 32,
#   'RH': 47,
#   'Ws': 14,
#   'Rain': 0.7,
#   'FFMC': 77.5,
#   'DMC': 7.1,
#   'DC': 8.8,
#   'ISI': 1.8}]

# %% [markdown]
# ### Connecting...

# %%
db = client['Algerian_Forest-Fires']

# %%
collection = db['Forest-Fires']

# %%
collection.insert_many(bulk_data)

# %%
ls = []
for i in collection.find():
    del i['_id']
    ls.append(i)

# %%
ls[:10]
# Out:
# [{'Temperature': 35,
#   'RH': 64,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 87.2,
#   'DMC': 31.9,
#   'DC': 145.7,
#   'ISI': 6.8},
#  {'Temperature': 36,
#   'RH': 45,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 78.8,
#   'DMC': 4.8,
#   'DC': 10.2,
#   'ISI': 2.0},
#  {'Temperature': 35,
#   'RH': 55,
#   'Ws': 12,
#   'Rain': 0.4,
#   'FFMC': 78.0,
#   'DMC': 5.8,
#   'DC': 10.0,
#   'ISI': 1.7},
#  {'Temperature': 35,
#   'RH': 63,
#   'Ws': 14,
#   'Rain': 0.3,
#   'FFMC': 76.6,
#   'DMC': 5.7,
#   'DC': 10.0,
#   'ISI': 1.7},
#  {'Temperature': 34,
#   'RH': 69,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 85.0,
#   'DMC': 8.2,
#   'DC': 19.8,
#   'ISI': 4.0},
#  {'Temperature': 34,
#   'RH': 65,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 86.8,
#   'DMC': 11.1,
#   'DC': 29.7,
#   'ISI': 5.2},
#  {'Temperature': 32,
#   'RH': 75,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 86.4,
#   'DMC': 13.0,
#   'DC': 39.1,
#   'ISI': 5.2},
#  {'Temperature': 32,
#   'RH': 69,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 86.5,
#   'DMC': 15.5,
#   'DC': 48.6,
#   'ISI': 5.5},
#  {'Temperature': 32,
#   'RH': 60,
#   'Ws': 18,
#   'Rain': 0.3,
#   'FFMC': 77.1,
#   'DMC': 11.3,
#   'DC': 47.0,
#   'ISI': 2.2},
#  {'Temperature': 35,
#   'RH': 59,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 87.4,
#   'DMC': 14.8,
#   'DC': 57.0,
#   'ISI': 6.9}]

# %%
pred_data = pd.DataFrame(ls[:10])

# %%
series = pred_data.to_numpy()

# %%
type(series)
# Out:
# numpy.ndarray

# %%
values = np.array(list(series)).reshape(len(series), -1)
values
# Out:
# array([[ 35. ,  64. ,  17. ,   0. ,  87.2,  31.9, 145.7,   6.8],
#        [ 36. ,  45. ,  14. ,   0. ,  78.8,   4.8,  10.2,   2. ],
#        [ 35. ,  55. ,  12. ,   0.4,  78. ,   5.8,  10. ,   1.7],
#        [ 35. ,  63. ,  14. ,   0.3,  76.6,   5.7,  10. ,   1.7],
#        [ 34. ,  69. ,  13. ,   0. ,  85. ,   8.2,  19.8,   4. ],
#        [ 34. ,  65. ,  13. ,   0. ,  86.8,  11.1,  29.7,   5.2],
#        [ 32. ,  75. ,  14. ,   0. ,  86.4,  13. ,  39.1,   5.2],
#        [ 32. ,  69. ,  16. ,   0. ,  86.5,  15.5,  48.6,   5.5],
#        [ 32. ,  60. ,  18. ,   0.3,  77.1,  11.3,  47. ,   2.2],
#        [ 35. ,  59. ,  17. ,   0. ,  87.4,  14.8,  57. ,   6.9]])

# %% [markdown]
# #### Testing:

# %%
import pickle

# %%
reg = pickle.load(open('Regression.pkl', 'rb'))
clas = pickle.load(open('Classification.pkl', 'rb'))
scale = pickle.load(open('Scaler_Transformed.pkl', 'rb'))

# %%
values = scale.transform(values)

# %%
clas.predict(values)
# Out:
# array([1, 0, 0, 0, 1, 1, 1, 1, 0, 1])
